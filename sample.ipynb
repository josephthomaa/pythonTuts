# %%
import pandas as pd
import matplotlib

# %%
df = pd.read_csv("archive/avocado.csv")
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.tail()
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7 2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
df.Date.head()
# Out:
# 0   2015-12-27
# 1   2015-12-20
# 2   2015-12-13
# 3   2015-12-06
# 4   2015-11-29
# Name: Date, dtype: datetime64[ns]

# %%
albany_df = df[df['region']=="Albany"]
albany_df.head()
# Out:
#    Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0           0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4 2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
albany_df = albany_df.set_index("Date")
albany_df.sort_index(inplace=True)

# %%
#albany_df['AveragePrice'].plot()
albany_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany_df["price25ma"] = albany_df["AveragePrice"].rolling(25).mean()

# %%
albany_df.tail()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# Date
# 2018-03-11           2          1.68       2570.52    131.67     229.56
# 2018-03-18           1          1.66       3154.45    275.89     297.96
# 2018-03-18           1          1.35     105304.65  13234.86   61037.58
# 2018-03-25           0          1.57     149396.50  16361.69  109045.03
# 2018-03-25           0          1.71       2321.82     42.95     272.41
#
#              4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2018-03-11   0.00     2209.29     2209.29        0.00          0.0
# 2018-03-18   0.00     2580.60     2577.27        3.33          0.0
# 2018-03-18  55.00    30977.21    26755.90     3721.31        500.0
# 2018-03-25  65.45    23924.33    19273.80     4270.53        380.0
# 2018-03-25   0.00     2006.46     1996.46       10.00          0.0
#
#                     type  year  region  price25ma
# Date
# 2018-03-11       organic  2018  Albany     1.4224
# 2018-03-18       organic  2018  Albany     1.4316
# 2018-03-18  conventional  2018  Albany     1.4276
# 2018-03-25  conventional  2018  Albany     1.4272
# 2018-03-25       organic  2018  Albany     1.4368

# %%
df.region.unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
ny_df = df.copy()[df.region == 'NewYork']
ny_df.head()
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume      4046       4225  \
# 1456           0 2015-12-27          1.17    1129876.05  13711.19  872603.60
# 1457           1 2015-12-20          1.23    1139347.98  13998.35  867406.68
# 1458           2 2015-12-13          1.12    1254805.29  15990.38  975504.52
# 1459           3 2015-12-06          1.20    1068971.54  15730.10  887708.08
# 1460           4 2015-11-29          1.16     999169.64  13652.41  814571.57
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 1456   894.58   242666.68   208470.99    34191.25         4.44  conventional
# 1457   803.83   257139.12   212615.20    44523.92         0.00  conventional
# 1458  1657.92   261652.47   222446.62    39205.85         0.00  conventional
# 1459   892.62   164640.74   136643.23    27997.51         0.00  conventional
# 1460   863.58   170082.08   139508.76    30573.32         0.00  conventional
#
#       year   region
# 1456  2015  NewYork
# 1457  2015  NewYork
# 1458  2015  NewYork
# 1459  2015  NewYork
# 1460  2015  NewYork

# %%
df = df.copy()[df['type']=='organic']
df["Date"] = pd.to_datetime(df["Date"])
df.sort_values(by="Date", ascending=True, inplace=True)
graph_df = pd.DataFrame()
for region in df.region.unique()[:8]:
    print(region)
    region_df = df.copy()[df['region'] == region]
    region_df.set_index('Date', inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"{region}_price25ma"] = region_df["AveragePrice"].rolling(25).mean()
    
    if graph_df.empty:
        graph_df = region_df[[f"{region}_price25ma"]]
    else:
        graph_df = graph_df.join(region_df[f"{region}_price25ma"])
# Out:
# California
# Roanoke
# Denver
# SanDiego
# GreatLakes
# RichmondNorfolk
# DallasFtWorth
# SanFrancisco

# %%
graph_df.tail()
# Out:
#             California_price25ma  Roanoke_price25ma  Denver_price25ma  \
# Date
# 2018-02-25                1.9128             1.6136            1.7084
# 2018-03-04                1.8876             1.5972            1.6880
# 2018-03-11                1.8636             1.5828            1.6708
# 2018-03-18                1.8516             1.5624            1.6700
# 2018-03-25                1.8364             1.5532            1.6568
#
#             SanDiego_price25ma  GreatLakes_price25ma  \
# Date
# 2018-02-25              2.0276                1.5656
# 2018-03-04              1.9988                1.5460
# 2018-03-11              1.9668                1.5248
# 2018-03-18              1.9476                1.5012
# 2018-03-25              1.9268                1.4912
#
#             RichmondNorfolk_price25ma  DallasFtWorth_price25ma  \
# Date
# 2018-02-25                     1.5244                   1.5708
# 2018-03-04                     1.5016                   1.5536
# 2018-03-11                     1.4920                   1.5340
# 2018-03-18                     1.4744                   1.5196
# 2018-03-25                     1.4672                   1.5100
#
#             SanFrancisco_price25ma
# Date
# 2018-02-25                  1.9960
# 2018-03-04                  1.9968
# 2018-03-11                  2.0016
# 2018-03-18                  1.9936
# 2018-03-25                  1.9776

# %%
graph_df.plot(figsize=(16,10))
# Out:
# <AxesSubplot:xlabel='Date'>
